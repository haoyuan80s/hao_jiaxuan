# %%
cd /data5/jiaxuan/hao_jiaxuan
# Out:
# /data5/jiaxuan/hao_jiaxuan

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import cv2 as cv

# %%
ls data/test_images/ | head
# Out:
# test_00145af3.jpg
# test_001c37e2.jpg
# test_003aa33a.jpg
# test_00665e33.jpg
# test_006964dc.jpg
# test_0082d2cd.jpg
# test_0086f578.jpg
# test_008bc9f0.jpg
# test_00912860.jpg
# test_0095f51b.jpg
# ls: write error

# %%
im = cv.imread('data/test_images/test_00145af3.jpg')
plt.imshow(im)
plt.show()

# %%
ls data/train_images/ | wc
# Out:
#    3881    3881   77920

# %%
with open('data/train.csv') as f:
    f.readlines()
